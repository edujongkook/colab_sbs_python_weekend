# %% [markdown]
# <a href="https://colab.research.google.com/github/edujongkook/colab_sbs_python_weekend/blob/main/python_%EA%B8%B0%EC%B4%88_8%EC%9D%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 8일차 강의 내용
# - random 모듈
# - 데이터 시각화
# - Matplotlib
# - wordcloud

# %% [markdown]
# ## matplotlib -p334

# %% [markdown]
# - 코랩에는 이미 matplotlib가 설치되어있음

# %%
# !pip install matplotlib

# %% [markdown]
# - 한글 폰트 설치 및 적용

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# - 메뉴 런타임 -> 런타임 다시 시작 후 아래 코드 실행

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ### subplot

# %% [markdown]
# ![subplot_03.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1, 1, 1)
plt.show()

# %%
figure = plt.figure()
axes1 = figure.add_subplot(1, 2, 1)
axes2 = figure.add_subplot(1, 2, 2)
plt.show()

# %%
figure = plt.figure()
axes1 = figure.add_subplot(2, 1, 1)
axes2 = figure.add_subplot(2, 1, 2)
plt.show()

# %%
figure = plt.figure()
axes1 = figure.add_subplot(2, 2, 1)
axes2 = figure.add_subplot(2, 2, 2)
axes3 = figure.add_subplot(2, 2, 3)
axes4 = figure.add_subplot(2, 2, 4)
plt.show()

# %% [markdown]
# ###  random 모듈

# %%
import random

print(random.random())  # 0 ~ 1 사이의 무작위 수 생성
print(random.randrange(1, 10))  #  randrange(start, end) start 포함 end 미만의 임의의 정수 생성
list_test = [1, 2, 3, 4, 5]
random.shuffle(list_test)  # 주어진 list 요소들의 순서를 무작위로 섞음
print(list_test)
print(random.choice(list_test))  # 주어진 list에서 무작위로 요소를 하나 선택

# %% [markdown]
# #### ✅ 10개의 요소가 1부터 100까지 무작위 값인 리스트 만들기

# %%
결과 예시:
 [91, 51, 87, 36, 78, 66, 65, 27, 15, 49]

# %% [markdown]
# ### plot() 함수 (선형 그래프) -p336

# %%
figure = plt.figure()
axes = figure.add_subplot(111)
x1 = [0, 1, 2, 3, 4]
y1 = [4, 1, 3, 5, 2]
x2 = x1
y2 = [2, 3, 6, 5, 4]
axes.plot(x1, y1)
axes.plot(x2, y2)
plt.show()

# %% [markdown]
# #### - plot 스타일

# %%
figure = plt.figure()
axes = figure.add_subplot(111)
axes.plot(x1, y1, 'ro-', linewidth=1.0)
axes.plot(x2, y2, color='m', marker='v')
plt.show()

# %% [markdown]
# #### - 라인, 마커, 색상 스타일 옵션 값

# %% [markdown]
# ![제목 없음.png](data:image/png;base64,...)

# %% [markdown]
# #### ✅기본예제 -p340

# %% [markdown]
# 상반기(1~6월)의 매출 데이터를 꺽은선형그래프로 나타내서 추세를 알아보는 프로그램입니다. 가로축(x축)은 Jan-Jun 까지 표시하고, 세로축(y축)은 매출액을 표시합니다.

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_subplot(111)
x = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
y = [1200, 800, 500, 400, 700, 800]
axes.plot(x, y, linestyle='--', marker='^')
plt.show()

# %% [markdown]
# #### sin(x) / cos(x) 그리기

# %%
import math

figure = plt.figure()
axes = figure.add_subplot(111)
list_x = []
list_sinx = []
list_cosx = []

for x in range(0, 100):
    list_x.append(x * 0.1)

for x in list_x:
    list_sinx.append(math.sin(x))
    list_cosx.append(math.cos(x))

axes.plot(list_x, list_sinx, linestyle='-')
axes.plot(list_x, list_cosx, 'r--')
plt.show()

# %% [markdown]
# ### bar() 함수(막대 그래프) -p341

# %% [markdown]
# #### - 라벨 / 제목 붙이기

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_subplot(111)
x = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
y = [8, 6, 5, 4, 7, 9, 5]
axes.bar(x, y)
#axes.plot(x, y, 'r-o')
plt.title('weekday call')  # 그래프의 제목
plt.xlabel('week')  # x축의 라벨
plt.ylabel('call')  # y축의 라벨
plt.show()

# %% [markdown]
# #### ✅응용예제 -p349

# %% [markdown]
# 다음 지시사항에 따라 랜덤 데이터를 생성후 그래프를 그리세요

# %% [markdown]
# 1. 총 2개의 데이터 (리스트)를 랜덤한 값으로 생성합니다. (범위는 0부터 100까지, 100개의 요소)
# 2. x축 데이터는 0부터 100까지 순서대로 값을 가지는 리스트입니다.
# 3. 하나의 subplot에 꺽은선그래프와 막대그래프를 동시에 배치합니다.
# 4. 꺽은선 그래프는 빨강색에 *모양의 마커를 적용
# 5. 막대그래프는 녹색을 적용하세요

# %%
결과예시:

# %% [markdown]
# ![다운로드 (1).png](data:image/png;base64,...)

# %% [markdown]
# ### scatter() 함수 (산포 그래프)

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_subplot(111)
x = [2, 4, 3, 4, 5, 1]
y = [6, 4, 1, 2, 7, 5]
area = [50, 100, 150, 200, 250, 300]  # 각 점의 크기
color = ['red', 'green', 'blue', 'orange', 'aqua', 'crimson']  # 각 점의 색상
axes.scatter(x, y, s=area, c=color, alpha=0.5)  # alpha : 각 점의 투명도
plt.show()

# %% [markdown]
# #### ✅ randrange scatter
# - randrange 매서드로 x, y 각각 10개의 요소를 가지는
# 리스트 2개를 생성 후(1 ~ 10범위) scatter() 함수로 그리기
# - 색과 점의 크기는 설정하지 않음

# %%
결과예시:

# %% [markdown]
# ![다운로드 (2).png](data:image/png;base64,...)

# %% [markdown]
# ### pie() 함수 (원형 그래프) -p344

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_subplot(111)
data = [1, 2, 3]
axes.pie(data)
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_subplot(111)
data = [1, 2, 3]
label = ['Good', 'Bad', 'Normal']
axes.pie(data, labels=label, autopct='%0d%%')
'''
autopct
%%  # %표시
# %d  # 정수
%0.1f  # 소수점 1자리까지
%0.2f  # 소수점 2자리까지
%0.3f%%  # 소수점 3자리까지 + % 표시
'''
plt.legend(label, loc='center left')
plt.axis('equal')
plt.show()

# %% [markdown]
# #### ✅ 고양시 음식점 종류 원형 그래프 그리기
# csv파일 (goyang_food.csv)를 읽어서 음식점 종류의 분포를 원형 그래프로 표현하기

# %% [markdown]
# 1. csv 파일 로드 (아래 링크에서 goyang_food.csv 다운로드후 코랩에 업로드)

# %% [markdown]
# 공유 드라이브 링크 : https://drive.google.com/drive/folders/1t7-xAaEejn-0SvOetcLQvUNYxUhy4Lj4?usp=drive_link

# %%
import csv
list_food = []  # 전체 음식점 정보가 담기는 리스트
with open('goyang_food.csv') as f:
    reader = csv.reader(f)
    for line in reader:  # 한줄씩 csv 파일을 읽어서
        list_food.append(line)  # 리스트에 추가

food_pie = list_food[1:]  # 맨 처음 요소에는 제목이 들어 있어서 슬라이스로 제외시킴
foods = []  # 음식점 종류만 담을 리스트
for food in food_pie:  # 음식점 전체 정보 리스트를 순회하면서
    foods.append(food[4])  # 음식점 종류가 담긴 5번째 요소만 추가

# %%
foods

# %% [markdown]
# 2. 각 음식점 종류가 몇개씩 있는지 세기 (리스트의 count() 매서드 사용)

# %%
foods.count('한식')

# %%
foods.count('중국식')

# %%
foods.count('일식')

# %%
len(foods)  # 전체 음식점종류 갯수

# %% [markdown]
# 3. pie() 함수를 사용해서 표현하기 (한식, 중국식, 일식, 나머지는 기타로 4가지만 표현)

# %%
결과:

# %% [markdown]
# ![다운로드 (3).png](data:image/png;base64,...)

# %% [markdown]
# ## wordcloud 모듈 -p346

# %% [markdown]
# - 코랩에 이미 설치되어 있음

# %%
# !pip install wordcloud

# %% [markdown]
# - p347 코드

# %%
import wordcloud
import matplotlib.pyplot as plt

words = {
    '파이썬' : 20,
    '빅데이터' : 5,
    '웹크롤링' : 7,
    '인공지능' : 9,
    '딥러닝' : 12
}

wc = wordcloud.WordCloud('NanumBarunGothic')
cloud = wc.generate_from_frequencies(words)
plt.figure()
plt.imshow(cloud)
plt.show()

# %% [markdown]
# #### ✅ 롤 챔프 랭커 wordcloud
# 게임 롤의 랭커들의 아이디와 점수가 들어있는 ranker.csv 파일을 불러와 각 챔피온의 이름과 점수로 wordcloud 그리기

# %% [markdown]
# 공유 드라이브 링크 : https://drive.google.com/drive/folders/1t7-xAaEejn-0SvOetcLQvUNYxUhy4Lj4?usp=drive_link

# %% [markdown]
# ranker.csv 파일 다운로드후 코랩에 업로드

# %% [markdown]
# - load_csv_file 함수

# %%
ranker_list[0]
# Out:
# ['랭크', '플레이어', '점수', '챔프']

# %%
import csv

def load_csv_file(file_name):
    """ 이 함수는 csv파일 전체 이름을 받아서
    한줄씩 리스트에 넣어서 돌려준다.
    ex) load_csv_file('file_name.csv') -> csv_list
    리턴되는 리스트는 요소로 리스트가 들어있다
    """
    csv_list = []
    with open(file_name) as f:
        reader = csv.reader(f)
        for line in reader:
            csv_list.append(line)

    return csv_list

# %% [markdown]
# 위의 함수로 불러온 리스트 구조

# %%
[['랭크', '플레이어', '점수', '챔프'],  # 첫번째 요소에는 불필요한 제목이 담겨있음
 ['1st', '대한민국일등가렌 (KR)', '9102855', '가렌'],
 ['2nd', '좀비77 (KR)', '8965322', '가렌'],
 ['3rd', 'nero2108 (EUW)', '8192888', '가렌'],
...
 ['50th', '갈리오 갈릴레이 (KR)', '1947710', '갈리오'],
 ['1st', 'taekomatigas (PH)', '7901479', '갱플랭크'],
 ['2nd', '王老吉開著老極湃 (TW)', '5426771', '갱플랭크'],
 ['3rd', 'SuperiorXemnas (EUW)', '5278703', '갱플랭크'],
 ['4th', 'Wings of Steel (EUW)', '5164932', '갱플랭크'],
...

# %% [markdown]
# 새롭게 만들 딕셔너리 구조

# %%
words =
 {'가렌': 306983158,  # 각 해당 챔프의 랭커들의 점수 총합
 '갈리오': 135408811,
 '갱플랭크': 199439665,
 '그라가스': 146980793,
 '그레이브즈': 161435306,
 '그웬': 68343199,
 '나르': 186798825,
 '나미': 243251048,
 '나서스': 216103186,
 '노틸러스': 189230919,
 '녹턴': 226462421,
 '누누와 윌럼프': 124425213
 ...
 ...
}

# %% [markdown]
# 1. load_csv_file 함수를 호출하여 리스트를 얻는다

# %%
ranker_list = load_csv_file('ranker.csv')

# %% [markdown]
# 2. 각 리스트를 하나씩 순회하며 필요한 정보(챔프의 이름을 key로 점수의 총합을 값으로 계산)를 새로운 딕셔너리에 담는다.
# 이 때 딕셔너리에 이미 그 챔프의 이름이 있는지 검사하는 조건문에 따라 있을 때와 없을 때의 수식이 분리된다.

# %% [markdown]
# 3. 완성된 딕셔너리를 예제 코드와 같이 wordcloud를 이용해 그린다
