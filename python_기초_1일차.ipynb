# %% [markdown]
# <a href="https://colab.research.google.com/github/edujongkook/colab_sbs_python_weekend/blob/main/python_%EA%B8%B0%EC%B4%88_1%EC%9D%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오늘의 강의 내용
# - 파이썬 소개, 변수와 자료형

# %% [markdown]
# # 파이썬 소개

# %% [markdown]
# ## TIOBE Index for python
# https://www.tiobe.com/tiobe-index/
# - 전세계에서의 파이썬 인기점수 13.45% / 1위 (2023.5)
# - 엔지니어의 수, 검색엔진에서 검색되는 빈도 등으로 점수 계산

# %% [markdown]
# ![tiobe_python.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 프로그래밍 언어 시각화
# https://exploring-data.com/vis/programming-languages-influence-network/ (2013)

# %% [markdown]
# ![ExData.png](data:image/png;base64,...)

# %% [markdown]
# * Python 의 특징
#
# 1.   객체지향(Object-Oriented)
# 2.   스크립트(Script, Interpreter)
# 3.   동적 타이핑(Dynamic Typing)

# %%
number = 10
text = "Hello"
print(text)
print(text * number)
print(text + number)

# %% [markdown]
# - java 케이스 :
# https://www.compilejava.net/

# %% [markdown]
# ---

# %% [markdown]
# ## python 활용영역

# %% [markdown]
# # 변수와 자료형
